# %%
import geoglows

# %%
stats = geoglows.streamflow.forecast_stats(12039943, 'token', api_source=geoglows.streamflow.BYU_ENDPOINT)
hist = geoglows.streamflow.historic_simulation(12039943, 'token', api_source=geoglows.streamflow.BYU_ENDPOINT)
rperiods = geoglows.streamflow.return_periods(12039943, 'token', api_source=geoglows.streamflow.BYU_ENDPOINT)

# %%
forecast_figure = geoglows.streamflow.forecast_plot(stats, rperiods, 12039943, outformat='plotly')
forecast_figure.show()
# Out:
# <div>
#
#
#             <div id="ca0622a1-2535-4216-a4f0-5755a02d5a00" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("ca0622a1-2535-4216-a4f0-5755a02d5a00")) {
#                     Plotly.newPlot(
#                         'ca0622a1-2535-4216-a4f0-5755a02d5a00',
# ...

# %%
historic_figure = geoglows.streamflow.historical_plot(hist, rperiods)
historic_figure.show()
# Out:
# <div>
#
#
#             <div id="46068607-220c-4a3c-9d12-8d662f1e8a8f" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("46068607-220c-4a3c-9d12-8d662f1e8a8f")) {
#                     Plotly.newPlot(
#                         '46068607-220c-4a3c-9d12-8d662f1e8a8f',
# ...
