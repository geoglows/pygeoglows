# %%
import geoglows

# %%
stats = geoglows.streamflow.forecast_stats(12039943)
ensembles = geoglows.streamflow.forecast_ensembles(12039943)
hist = geoglows.streamflow.historic_simulation(12039943)
rperiods = geoglows.streamflow.return_periods(12039943)
seasonal = geoglows.streamflow.seasonal_average(12039943)

# %%
forecast_figure = geoglows.streamflow.forecast_plot(stats, rperiods, 12039943)
forecast_figure.show()

# %%
ensembles_figure = geoglows.streamflow.ensembles_plot(ensembles, rperiods, 12039943)
ensembles_figure.show()

# %%
historic_figure = geoglows.streamflow.historical_plot(hist, rperiods, 12039943)
historic_figure.show()

# %%
seasonal_figure = geoglows.streamflow.seasonal_plot(seasonal, 12039943)
seasonal_figure.show()
